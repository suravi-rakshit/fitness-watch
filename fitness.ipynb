# %%
import pandas as pd
data=pd.read_excel("SAYANI.X.xlsx")
print(data.head())
# Out:
#     Date      Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0  45006  0.667627          46   0.02543         14.620                3
# 1  45006  0.679595         645   0.40041         14.722                3
# 2  45006  0.688634          14   0.00996         14.603                4
# 3  45006  0.698345          13   0.00901         14.811                3
# 4  45006  0.715625          17   0.00904         15.153                3
#
#    Walking Double Support Percentage  Walking Speed
# 0                              0.304          3.060
# 1                              0.309          3.852
# 2                              0.278          3.996
# 3                              0.278          5.040
# 4                              0.281          5.184

# %%
data.isnull()
# Out:
#       Date   Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0    False  False       False     False          False            False
# 1    False  False       False     False          False            False
# 2    False  False       False     False          False            False
# 3    False  False       False     False          False            False
# 4    False  False       False     False          False            False
# ..     ...    ...         ...       ...            ...              ...
# 144  False  False       False     False          False            False
# 145  False  False       False     False          False            False
# 146  False  False       False     False          False            False
# 147  False  False       False     False          False            False
# 148  False  False       False     False          False            False
#
#      Walking Double Support Percentage  Walking Speed
# 0                                False          False
# 1                                False          False
# 2                                False          False
# 3                                False          False
# 4                                False          False
# ..                                 ...            ...
# 144                              False          False
# 145                              False          False
# 146                              False          False
# 147                              False          False
# 148                              False          False
#
# [149 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("SAYANI.X.xlsx")
df=pd.DataFrame(data)
print(df)
plt.scatter(df["Flights Climbed"],df["Step Count"])
plt.xlabel("Flights Climbed",fontsize=20)
plt.ylabel("Step Count",fontsize=20)
plt.show()
# Out:
#       Date      Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0    45006  0.667627          46   0.02543         14.620                3
# 1    45006  0.679595         645   0.40041         14.722                3
# 2    45006  0.688634          14   0.00996         14.603                4
# 3    45006  0.698345          13   0.00901         14.811                3
# 4    45006  0.715625          17   0.00904         15.153                3
# ..     ...       ...         ...       ...            ...              ...
# 144  45017  0.669711          87   0.05872         13.162                3
# 145  45017  0.689792          37   0.02039          4.135                1
# 146  45017  0.701262         969   0.65379         31.416                3
# 147  45017  0.714653         640   0.42356         13.250                6
# 148  45017  0.741053        1081   0.67835         14.131                1
#
#      Walking Double Support Percentage  Walking Speed
# 0                                0.304          3.060
# 1                                0.309          3.852
# 2                                0.278          3.996
# 3                                0.278          5.040
# 4                                0.281          5.184
# ..                                 ...            ...
# 144                              0.298          5.364
# 145                              0.295          5.400
# 146                              0.274          5.292
# 147                              0.282          4.860
# 148                              0.265          5.040
#
# [149 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("SAYANI.X.xlsx")
df=pd.DataFrame(data)
print(df)
plt.bar(df["Flights Climbed"],df["Step Count"])
plt.xlabel("Flights Climbed",fontsize=20)
plt.ylabel("Step Count",fontsize=20)
plt.show()
# Out:
#       Date      Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0    45006  0.667627          46   0.02543         14.620                3
# 1    45006  0.679595         645   0.40041         14.722                3
# 2    45006  0.688634          14   0.00996         14.603                4
# 3    45006  0.698345          13   0.00901         14.811                3
# 4    45006  0.715625          17   0.00904         15.153                3
# ..     ...       ...         ...       ...            ...              ...
# 144  45017  0.669711          87   0.05872         13.162                3
# 145  45017  0.689792          37   0.02039          4.135                1
# 146  45017  0.701262         969   0.65379         31.416                3
# 147  45017  0.714653         640   0.42356         13.250                6
# 148  45017  0.741053        1081   0.67835         14.131                1
#
#      Walking Double Support Percentage  Walking Speed
# 0                                0.304          3.060
# 1                                0.309          3.852
# 2                                0.278          3.996
# 3                                0.278          5.040
# 4                                0.281          5.184
# ..                                 ...            ...
# 144                              0.298          5.364
# 145                              0.295          5.400
# 146                              0.274          5.292
# 147                              0.282          4.860
# 148                              0.265          5.040
#
# [149 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("SAYANI.X.xlsx")
df=pd.DataFrame(data)
print(df)
grouped_by=df.groupby("Time")["Distance"].sum()
print(grouped_by)
plt.plot(grouped_by.index,grouped_by.values)
plt.xlabel("Time",fontsize=20)
plt.ylabel("Distance",fontsize=20)
plt.show()
# Out:
#       Date      Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0    45006  0.667627          46   0.02543         14.620                3
# 1    45006  0.679595         645   0.40041         14.722                3
# 2    45006  0.688634          14   0.00996         14.603                4
# 3    45006  0.698345          13   0.00901         14.811                3
# 4    45006  0.715625          17   0.00904         15.153                3
# ..     ...       ...         ...       ...            ...              ...
# 144  45017  0.669711          87   0.05872         13.162                3
# 145  45017  0.689792          37   0.02039          4.135                1
# 146  45017  0.701262         969   0.65379         31.416                3
# 147  45017  0.714653         640   0.42356         13.250                6
# 148  45017  0.741053        1081   0.67835         14.131                1
#
#      Walking Double Support Percentage  Walking Speed
# 0                                0.304          3.060
# 1                                0.309          3.852
# 2                                0.278          3.996
# 3                                0.278          5.040
# 4                                0.281          5.184
# ..                                 ...            ...
# 144                              0.298          5.364
# 145                              0.295          5.400
# 146                              0.274          5.292
# 147                              0.282          4.860
# 148                              0.265          5.040
#
# [149 rows x 8 columns]
# Time
# 0.005787    0.02504
# 0.022396    0.01855
# 0.050868    0.00639
# 0.056181    0.01026
# 0.063808    0.00588
#              ...
# 0.965683    0.05934
# 0.972106    0.01402
# 0.973495    0.01680
# 0.975313    0.01248
# 0.979051    0.00690
# Name: Distance, Length: 148, dtype: float64
